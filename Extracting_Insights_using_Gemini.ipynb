# %% [markdown]
# ##Import LIbraries

# %%
import os

import google.generativeai as genai

# %% [markdown]
# ##Model Setup

# %%
# configure API Key
genai.configure(api_key="")

# %%
# Create the model
# See https://ai.google.dev/api/python/google/generativeai/GenerativeModel
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

# %%
model = genai.GenerativeModel(
  model_name="gemini-3-flash-preview",
  generation_config=generation_config,
  # safety_settings = Adjust safety settings
  # See https://ai.google.dev/gemini-api/docs/safety-settings
)

# %% [markdown]
# ##Start a Chat Seesion

# %%
chat_session = model.start_chat(
  history=[
    {
      "role": "user",
      "parts": [
        "You are a market research analyst specializing in consumer electronics.\\n",
      ],
    }
  ]
)

# %%
# Test different prompts
response1 = chat_session.send_message("What are the key factors customers consider when buying earbuds?")
print(response1.text)
# Out:
# As a market research analyst specializing in consumer electronics, I’ve tracked the rapid evolution of the "hearables" market. While price used to be the primary driver, the commoditization of high-end features has shifted consumer priorities toward a more holistic "user experience."
#
# Here are the key factors customers consider when purchasing earbuds, categorized by their impact on the buying decision:
#
# ### 1. Audio Performance and Sound Profile
# Sound remains the foundational requirement, but consumer preferences have become more nuanced:
# *   **Signature Tuning:** Most mainstream consumers look for a "V-shaped" sound profile (boosted bass and treble). However, audiophiles prioritize a flat, neutral response or the ability to customize EQ via an app.
# *   **Codec Support:** Savvy tech buyers look for high-resolution codecs like **LDAC, aptX Adaptive, or AAC** (for iOS users) to ensure minimal data loss during Bluetooth transmission.
# *   **Spatial Audio:** With the rise of Atmos-mastered tracks and immersive movies, head-tracking and spatial audio have become major selling points for premium models.
#
# ### 2. Active Noise Cancellation (ANC) and Transparency
# In a post-pandemic world where "work from anywhere" is common, environmental control is non-negotiable.
# *   **ANC Quality:** Customers evaluate how well earbuds block out low-frequency hums (engines) and mid-range chatter (offices).
# *   **Transparency Mode:** This is now just as important as ANC. Users want a "natural" sounding transparency mode that allows them to hear their surroundings without a "hissing" digital overlay.
#
# ### 3. Ergonomics, Fit, and Comfort
# Since earbuds are often worn for hours, physical design is a frequent "dealbreaker" in reviews.
# *   **Form Factor:** The choice between "stem" designs (like AirPods) and "bud" designs (like Sony or Samsung).
# *   **Weight and Pressure:** Consumers look for vented designs that prevent the "clogged ear" feeling (occlusion effect).
# *   **Stability:** For the fitness demographic, the inclusion of "wingtips" or ear hooks is a primary search filter.
#
# ### 4. Battery Life and Charging Efficiency
# The "anxiety" factor is real in wireless audio.
# *   **Total Playtime:** The industry standard has shifted to 6–8 hours per charge for the buds, with an additional 20+ hours in the case.
# *   **Quick Charging:** This is a high-intent feature (e.g., "10 minutes of charging equals 1 hour of playback").
# *   **Wireless Charging:** Qi-compatibility for the case is increasingly expected in the $100+ price bracket.
#
# ### 5. Connectivity and Ecosystem Integration
# This is where brand loyalty is forged.
# *   **Multipoint Connectivity:** This is currently one of the most requested features, allowing users to stay connected to both a laptop and a phone simultaneously.
# *   **Ecosystem "Stickiness":** Features like "Instant Pairing" or "Find My" integration keep users locked into specific brands (Apple, Google, Samsung).
# *   **Mic Quality:** As earbuds replace traditional headsets for Zoom/Teams calls, beamforming microphones and AI wind-reduction are critical for professional buyers.
#
# ### 6. Durability and IP Ratings
# The "lifestyle" use case dictates the durability requirement:
# *   **IPX4:** The baseline for sweat and splash resistance.
# *   **IP57/67:** Increasingly sought after by outdoor enthusiasts for complete dust and water immersion protection.
#
# ### 7. Price-to-Value Ratio (The "Sweet Spot")
# The market is currently bifurcated:
# *   **The Premium Tier ($200+):** Dominated by Apple, Sony, and Bose. Buyers here prioritize brand prestige, best-in-class ANC, and ecosystem perks.
# *   **The "Value King" Tier ($50–$120):** This is the most competitive segment. Brands like EarFun, Soundcore, and Jabra win here by offering 90% of premium features at 40% of the cost.
#
# ### Market Analyst Insight: The "Invisible" Factor
# **Software Support.** Consumers are increasingly wary of "disposable" tech. They now look for brands that offer frequent **Firmware Updates** that improve ANC or add features (like Multipoint) post-purchase. A robust companion app is no longer a luxury; it is a requirement for a 5-star product rating.

# %%
response2 = chat_session.send_message("How would you analyze customer feedback about sound quality?")
print(response2.text)
# Out:
# Analyzing customer feedback on sound quality requires a blend of **Sentiment Analysis (NLP)**, **Technical Decoding**, and **Contextual Segmentation**. Unlike battery life, which is objective, sound quality is deeply subjective.
#
# As an analyst, I don't just look at *if* people like the sound; I look for *why* they like it and how their descriptions correlate with the product's actual frequency response.
#
# Here is the framework I use to analyze sound quality feedback:
#
# ### 1. Decoding "Layman" Vocabulary into Technical Metrics
# Customers rarely use terms like "frequency response." They use descriptive, emotive language. A key part of the analysis is translating these "buzzwords" into actionable engineering data:
#
# *   **"Muddy" or "Muffled":** This usually indicates a bloated lower-midrange or a lack of high-frequency extension. It suggests the drivers aren't separating frequencies well.
# *   **"Tinny" or "Thin":** This points to a lack of sub-bass or a boost in the upper-mids without enough low-end support.
# *   **"Punchy" or "Warm":** This is generally positive feedback for a emphasized mid-bass (the "thump") and a smooth high-end.
# *   **"Shrill" or "Piercing":** This indicates a spike in the 5kHz–8kHz range, which causes listener fatigue.
# *   **"Airy" or "Detailed":** This suggests good treble extension and a wide soundstage, often found in high-end drivers (like planar magnetic or balanced armatures).
#
# ### 2. Segmenting Feedback by User Persona
# Not all "bad" reviews mean the sound is poor; often, it’s a **mismatch between the product and the user.** I categorize feedback based on the reviewer's profile:
# *   **The "Basshead":** Will rate a neutral, high-fidelity earbud poorly because it lacks "rumble."
# *   **The Audiophile:** Will complain about "DSP (Digital Signal Processing) artifacts" or "compressed highs" that a general consumer wouldn't notice.
# *   **The Commuter/Office Worker:** Often prioritizes vocal clarity (mids) for podcasts and calls over musicality.
#
# ### 3. The "Expectation vs. Reality" Gap Analysis
# I look for trends where the marketing claims clash with user experience.
# *   **Example:** If the marketing highlights "Studio Grade Sound" but reviews mention "heavy bass," there is a **positioning error**. The product is attracting the wrong audience, which will lead to a high return rate and lower average star ratings even if the product is technically good.
#
# ### 4. Qualitative Sentiment Mapping (NLP)
# Using Natural Language Processing (NLP) tools, I aggregate thousands of reviews to create a **feature-sentiment map**.
# *   I look for the *frequency* of sound-related keywords paired with *sentiment polarity*.
# *   *Insight Example:* "If 40% of negative reviews mention 'static' or 'hiss' when ANC is on, it indicates a hardware floor-noise issue rather than a tuning preference."
#
# ### 5. Contextual Performance (The "Where" and "How")
# Sound quality feedback is heavily influenced by the environment. I analyze feedback for mentions of:
# *   **Fit/Seal:** Many "poor sound" complaints are actually "poor fit" complaints. If a user can’t get a good seal, the bass disappears. If I see a pattern of "thin sound," I check if users are also complaining about the provided ear tip sizes.
# *   **Codec Usage:** Sometimes negative sound reviews come from users on a specific OS (e.g., using an SBC codec on Windows vs. AAC on iPhone).
#
# ### 6. Competitive Benchmarking
# I use a **Relative Sentiment Score**. If a brand's "Clarity" sentiment is 75% positive, that sounds good—until you see the direct competitor is at 90%.
# *   I track "migration feedback": "I switched from [Competitor] to these, and the sound feels 'veiled'." This is the most valuable data point for understanding market share shifts.
#
# ### Summary for Stakeholders
# When presenting this to a product team, I would summarize it into a **Sound Quadrant**:
# 1.  **Strengths:** (e.g., "Industry-leading bass impact")
# 2.  **Weaknesses:** (e.g., "High-frequency fatigue after 30 mins")
# 3.  **Technical Fixes:** (e.g., "Recalibrate EQ at 7kHz via firmware")
# 4.  **Marketing Fixes:** (e.g., "Stop using the word 'Neutral' in ads; emphasize 'Powerful Bass' instead")

# %% [markdown]
# ##Integrating Gemini AI my Your Dataset

# %%
import pandas as pd
import google.generativeai as genai

#allowing accesss to my drive
from google.colab import drive
drive.mount('/content/drive')

# Load your dataset
df = pd.read_csv('/content/drive/My Drive/cleaned_dataset(1).csv')

# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyCyQ8Rnb7ft5MCt9Ad8Ay4EA9yEWKAnPP8"

# Function to analyze reviews using Gemini AI
def analyze_reviews(reviews, api_key,prompt_message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-3-flash-preview",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    prompt = prompt_message + "\n\n".join(reviews)
    response = chat_session.send_message(prompt)
    return response.text
# Out:
# Mounted at /content/drive

# %%
# Select reviews to analyze
reviews = df['content'].head(100).tolist()

# Create your prompt
prompt_message = "Analyze the following reviews and summarize the key insights:"

# Get insights
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# Based on the detailed reviews provided, here is a summary of the key insights regarding the **1More ComfoBuds Mini**.
#
# ### **1. Standout Feature: Size and Comfort**
# *   **Small Ear Friendly:** These are widely praised as the best earbuds on the market for people with small ears. They are significantly smaller than competitors (Sony, Samsung, Apple).
# *   **The "Sleep King":** Though not marketed exclusively for sleep, many reviewers consider these the ultimate sleep earbuds. Their flat, tiny profile allows side sleepers to use them without pain or pressure.
# *   **Discreet:** They sit flush in the ear, making them nearly invisible from the front and ideal for use under helmets (motorcycle/bicycle) or headbands.
#
# ### **2. Performance: Sound and ANC**
# *   **Sound Quality:** Generally rated as "good" to "very good" for the size. While they lack the sub-bass and soundstage of larger premium buds (like the 1More EVO or Sony XM4s), they are considered "punchy" and clear.
# *   **ANC Capabilities:** Most users were impressed that ANC exists at this size. It is effective at blocking constant low-frequency noise (fans, engine hums, snoring), though it does not reach the "silence" levels of Bose or Sony.
# *   **The "Wind Noise" Mode:** A specific standout for outdoor enthusiasts; the wind-reduction mode is noted to outperform Samsung and Apple for cycling and running.
#
# ### **3. Major Pain Points: Software and Controls**
# *   **The Sound ID Controversy:** Instead of a traditional manual Equalizer, 1More uses "Sound ID" (an A/B testing profile creator). Reviewers almost universally dislike this, finding it restrictive and often resulting in worse sound than the factory preset.
# *   **Limited Tap Controls:** To prevent accidental triggers (due to the small surface area), there is no "single tap" function. Users find the double/triple-tap customization too limited, specifically noting the **lack of on-bud volume control.**
# *   **App Stability:** Several reviewers reported that the 1More app is "buggy," occasionally crashes, or requires the user to toggle ANC modes manually every time they are used.
#
# ### **4. Critical Concern: Quality Control and Durability**
# This is the most polarizing aspect of the reviews. There is a high frequency of reported hardware failures:
# *   **The "Death Squeal":** Multiple users reported a high-pitched ringing or feedback loop in one earbud (often the right) after a few weeks or months of use.
# *   **Volume Drop:** A common issue where one bud becomes significantly quieter than the other.
# *   **The "Earwax Debate":** Some users claim these "failures" are actually just the tiny mesh holes getting clogged with earwax, requiring deep cleaning to restore sound. However, others insist they experienced failures even with pristine maintenance, suggesting internal hardware or moisture issues.
#
# ### **5. Battery and Connectivity**
# *   **Battery Life:** Rated at about 5 hours with ANC and 6 without. While lower than larger buds, most find this "remarkable" given the physical size.
# *   **Charging:** The case is tiny, supports USB-C and **Wireless Charging**, which is a rare premium feature at this price point ($80–$100 range).
# *   **Connection:** Generally strong (Bluetooth 5.2), but lacks **Multipoint** (connecting to two devices at once), which frustrated some tech-heavy users.
#
# ---
#
# ### **Final Verdict Summary**
# **Buy them if:** You have small ears, you are a side sleeper, or you need the most discreet earbuds possible for under a helmet. The form factor is currently unmatched in the industry.
#
# **Avoid them if:** You are an audiophile who needs a manual EQ, you are frustrated by limited touch controls, or you don't want to risk the "volume drop" issues that appear to plague 1More’s quality control.

# %%
df.head()
# Out:
#         review_id  product_id  \
# 0   RUE030N50F9EJ  B09PYVXXW5
# 1  R385JSD6KWP2QU  B09PYVXXW5
# 2  R1UB1V4EPP9MN3  B09PYVXXW5
# 3   RWYK1GXIVV6H1  B09PYVXXW5
# 4  R3FBQBGQM3II4W  B09PYVXXW5
#
#                                                title    author  rating  \
# 0  5.0 out of 5 stars Really good with a couple o...       CTM       5
# 1  4.0 out of 5 stars I wish I could rate 5 stars...    Gianna       4
# 2  5.0 out of 5 stars Basically perfect, fantasti...  Colin M.       5
# 3            1.0 out of 5 stars Decent but Defective    Aquila       1
# 4   3.0 out of 5 stars I went with soundcore instead   Frankie       3
#
#                                              content  \
# 0  I love TWS earbuds. I have many including buds...
# 1  …I just can’t. Because as useful as these earb...
# 2  I needed a replacement for my Galaxy buds pro'...
# 3  UPDATE 6/24/22: As of 6/23/22, my replacement ...
# 4  So out of the box these tiny buds surprised me...
#
#                                         timestamp  \
# 0      Reviewed in the United States May 14, 2022
# 1     Reviewed in the United States July 22, 2023
# 2   Reviewed in the United States August 18, 2022
# 3      Reviewed in the United States June 3, 2022
# 4  Reviewed in the United States October 28, 2022
#
#                      profile_id  is_verified  helpful_count  \
# 0  AEGYSY5H3ZUJC4SGGPRM3Z2OE5PA            1             32
# 1  AHINA7A6O2I5RZSNAY4OWYN4QXVA            1             31
# 2  AFG2T5XGMQCACK7JBDRHKEKWJLPA            1             21
# 3  AGFUWY2GO4HF5RMLUR7ZOSKID4KA            1              9
# 4  AEOFU2SCDWYLS6DTSXIR6FWMRQMQ            1              7
#
#   product_attributes                                       product_name  \
# 0       Color: Black  ComfoBuds Mini Hybrid Active Noise Cancelling ...
# 1         Color: Red  ComfoBuds Mini Hybrid Active Noise Cancelling ...
# 2         Color: Red  ComfoBuds Mini Hybrid Active Noise Cancelling ...
# 3       Color: Black  ComfoBuds Mini Hybrid Active Noise Cancelling ...
# 4       Color: Black  ComfoBuds Mini Hybrid Active Noise Cancelling ...
#
#   Rating Category  Year
# 0        Positive  2022
# 1        Positive  2023
# 2        Positive  2022
# 3        Negative  2022
# 4         Neutral  2022

# %% [markdown]
# ##Organising Product Information

# %%
# Check unique products in your dataset
unique_products = df['product_name'].unique()
print("Products in dataset:")
for product in unique_products:
    print(f"- {product}")
# Out:
# Products in dataset:
# - ComfoBuds Mini Hybrid Active Noise Cancelling Earbuds
# - HTC Earbuds Charging Case
# - JBL Tune 230NC TWS - True Wireless In-Ear Headphone
# - JLab Go Air Pop True Wireless Bluetooth Earbuds
# - Beats Studio Buds
# - Jabra Elite 4 True Wireless Earbuds
# - Sennheiser Consumer Audio CX True Wireless Earbuds
# - Skullcandy Smokin’ Buds Wireless Earbuds
# - Sony WF Earbud
# - Soundcore by Anker Life Earbuds
# - Apple AirPods Wireless Ear Buds

# %%
# Create a mapping dictionary for product names
# NOTE: CREATE MAPPING FOR YOUR PRODUCTS HERE
product_mapping = {
    "ComfoBuds Mini Hybrid Active Noise Cancelling Earbuds":{
        "short_name": "ComfoBuds Mini Hybrid Earbuds",
        "brand":"Comfo",
    },
    "HTC Earbuds Charging Case":{
        "short_name": "HTC Earbuds Charging Case",
        "brand":"HTC",
    },
    "JBL Tune 230NC TWS - True Wireless In-Ear Headphone":{
        "short_name": "JBL Tune 230NC Headphone",
        "brand":"JBL",
    },
    "JLab Go Air Pop True Wireless Bluetooth Earbuds": {
        "short_name": "JLab Go Air Pop Earbuds",
        "brand": "JLab",
    },
    "Beats Studio Buds": {
        "short_name": "Beats Studio Buds",
        "brand": "Beats",
    },
    "Jabra Elite 4 True Wireless Earbuds": {
        "short_name": "Jabra Elite 4 Earbuds",
        "brand": "Jabra",
    },
    "Sennheiser Consumer Audio CX True Wireless Earbuds": {
        "short_name": "Sennheiser CX True Wireless Earbuds",
        "brand": "Sennheiser",
    },
    "Skullcandy Smokin’ Buds Wireless Earbuds": {
        "short_name": "Skullcandy Smokin' Buds",
        "brand": "Skullcandy",
    },
    "Sony WF Earbud": {
        "short_name": "Sony WF Earbud",
        "brand": "Sony",
    },
    "Soundcore by Anker Life Earbuds": {
        "short_name": "Soundcore Life Earbuds",
        "brand": "Soundcore by Anker",
    },
    "Apple AirPods Wireless Ear Buds": {
        "short_name": "Apple AirPods Earbuds",
        "brand": "Apple",
    },
}

# %%
# Function to apply the mapping to your dataset
def clean_product_info(df, mapping):
    # Create new columns using the mapping
    df['short_name'] = df['product_name'].map({k: v['short_name'] for k, v in mapping.items()})
    df['brand'] = df['product_name'].map({k: v['brand'] for k, v in mapping.items()})

    # Handle any products not in mapping
    df['short_name'] = df['short_name'].fillna(df['product_name'])
    df['brand'] = df['brand'].fillna('Unknown')

    return df

# %%
# Clean your dataset
df = clean_product_info(df, product_mapping)

# View the results
print("\\nSample of cleaned data:")
print(df[['product_name', 'short_name', 'brand']].head())
# Out:
# \nSample of cleaned data:
#                                         product_name  \
# 0  ComfoBuds Mini Hybrid Active Noise Cancelling ...
# 1  ComfoBuds Mini Hybrid Active Noise Cancelling ...
# 2  ComfoBuds Mini Hybrid Active Noise Cancelling ...
# 3  ComfoBuds Mini Hybrid Active Noise Cancelling ...
# 4  ComfoBuds Mini Hybrid Active Noise Cancelling ...
#
#                       short_name  brand
# 0  ComfoBuds Mini Hybrid Earbuds  Comfo
# 1  ComfoBuds Mini Hybrid Earbuds  Comfo
# 2  ComfoBuds Mini Hybrid Earbuds  Comfo
# 3  ComfoBuds Mini Hybrid Earbuds  Comfo
# 4  ComfoBuds Mini Hybrid Earbuds  Comfo

# %% [markdown]
# ##Adding Sentiment Information

# %%
from textblob import TextBlob

def add_sentiment_info(df):
    # Add sentiment scores
    df['sentiment_score'] = df['content'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)

    # Categorize sentiments
    df['sentiment_category'] = df['sentiment_score'].apply(lambda x:
        'Positive' if x > 0.1
        else 'Negative' if x < -0.1
        else 'Neutral')

    return df

# %%
# Add sentiment information
df = add_sentiment_info(df)

# Quick view of sentiment distribution
print("\\nSentiment Distribution:")
print(df['sentiment_category'].value_counts()*100/len(df))
# Out:
# \nSentiment Distribution:
# sentiment_category
# Positive    79.144385
# Neutral     18.538324
# Negative     2.317291
# Name: count, dtype: float64

# %%
def analyze_basic_product(reviews, product_name):
    prompt_message = f"""Analyze these reviews for {product_name}:
    1. What are the top 3 most mentioned features?
    2. What do customers love most about this product?
    3. What are the most common complaints?

    Please provide specific examples from the reviews."""


    return analyze_reviews(reviews, api_key, prompt_message)

# %%
# Example: Analyze a single product
product_reviews = df[df['short_name'] == 'Beats Studio Buds']['content'].tolist()[:30]

basic_insights = analyze_basic_product(product_reviews, 'Beats Studio Buds')
print(basic_insights)
# Out:
# Based on the reviews provided, here is an analysis of the Beats Studio Buds:
#
# ### 1. Top 3 Most Mentioned Features
# *   **Physical "Clicky" Buttons:** Unlike many competitors that use touch-sensitive sensors, these buds feature a tactile manual button.
#     *   *Example:* One reviewer noted, "You press in and hear/feel the click... no need to guess if you tapped them once or twice."
# *   **Bass-Heavy Sound Profile:** The audio is repeatedly described as being tuned specifically for bass performance rather than "audiophile" balance.
#     *   *Example:* A customer mentioned, "These are for the people who like bass and want to feel some gravitas in their ears!"
# *   **Active Noise Cancellation (ANC) & Transparency Mode:** Most reviewers discussed the ability to toggle between blocking noise and hearing surroundings.
#     *   *Example:* Reviews noted they have "awareness mode, as well as a noise isolation mode," though the effectiveness of these features was a major point of contention.
#
# ### 2. What Customers Love Most
# *   **Seamless iPhone Connectivity:** Users heavily praised how the buds integrate with the Apple ecosystem, mimicking the AirPods experience.
#     *   *Example:* "These connect effortlessly to iPhone, as if they were AirPods. It was the single biggest factor that blew me away."
# *   **The Tactile Controls:** Many customers expressed a deep dislike for "touch sensors" and loved the reliability of the physical button.
#     *   *Example:* "I personally hate the sensor buttons because adjusting your earbuds in your ears would trigger the controls... the earbuds HAVE AN ACTUAL BUTTON."
# *   **Value (When on Sale):** When purchased at a discount (around $75–$80), customers felt the performance-to-price ratio was excellent.
#     *   *Example:* "These are 100% worth the $75 I spent on them, but NO WAY ARE THEY WORTH THE $150 RETAIL."
#
# ### 3. Most Common Complaints
# *   **Poor Fit/Stability During Activity:** The most frequent complaint is that the earbuds fall out easily, especially when the user is sweating, chewing, or moving their head.
#     *   *Example:* "Tested during a workout, a little bit of sweat had these sliding right out of my ear," and another mentioned they "fall out of my ears if I do simple things like turn my head or chew."
# *   **Flimsy Case Quality:** The charging case is often described as feeling cheap or fragile compared to other brands.
#     *   *Example:* One user called it "the flimsiest of any I had tested, with a very weak hinge," while another said it "feels like cheap plastic."
# *   **Poor Microphone Performance:** Several users reported that the earbuds are unsuitable for professional calls or video conferencing.
#     *   *Example:* "Microphone quality lacks... sounds horrible and robotic on a PC, making it unusable for video conferencing."
# *   **Inconsistent Noise Cancellation:** While listed as a feature, many felt the ANC was weak or produced distracting background artifacts.
#     *   *Example:* "Noise cancellation is a joke, it sounds the same as when it’s on transparent mode or off," and another noted it "introduces a persistent noise layer, similar to wind."

# %% [markdown]
# ## Sentiment-Based Analysis

# %%
def analyze_sentiment_patterns(reviews, sentiment_category, product_name):
    prompt_message = f"""Analyze these {sentiment_category.lower()} reviews for {product_name}:
    1. What specific aspects create {sentiment_category.lower()} reactions?
    2. Identify common phrases or descriptions used
    3. Note any comparisons with competitor products
    4. Find unexpected or unique feedback

    Support your analysis with specific examples."""

    return analyze_reviews(reviews, api_key, prompt_message)

# %%
# Example: Analyze positive reviews for a product
positive_reviews = df[
    (df['short_name'] == 'Beats Studio Buds') &
    (df['sentiment_category'] == 'Positive')
]['content'].tolist()[:30]

positive_insights = analyze_sentiment_patterns(
    positive_reviews,
    'Positive',
    'Beats Studio Buds'
)
print(positive_insights)
# Out:
# Based on the reviews provided, here is an analysis of the positive reactions to the Beats Studio Buds:
#
# ### 1. Specific Aspects Creating Positive Reactions
# *   **Physical "Clicky" Buttons:** This is the most praised feature. Users expressed relief at having a manual button rather than sensitive touch sensors. One reviewer noted they "hate the sensor buttons" because adjustments trigger unwanted controls, while the Studio Buds allow for a sure "press and feel."
# *   **Bass-Heavy Sound Profile:** Reviewers frequently mentioned the sound is "catered towards more bassy genres." It was described as having "punch," "gravitas," and "heavy kicks" that benefit metal, EDM, and hip-hop.
# *   **Seamless Connectivity:** The "Apple-like" pairing experience is a major highlight. One user stated it was the "single biggest factor that blew me away," noting they connect to an iPhone as effortlessly as AirPods do.
# *   **Aesthetics and Color Variety:** The visual appeal, specifically the "vibrant colors" like red and pink, creates strong positive sentiment. One user bought them specifically because their fiancé "loves pink," while another called the "classic look" a pro.
# *   **Durability and Resilience:** Several users were surprised by the product's ability to survive extreme accidents, including being dropped in a sink, being "baked" in a hot oven, and surviving "the washer and dryer three times."
#
# ### 2. Common Phrases and Descriptions
# *   **"Clicky buttons":** Used repeatedly to describe the tactile feedback of the controls.
# *   **"Bang for the buck":** Often used when the product is purchased on sale (specifically around the $75-$80 price point).
# *   **"Punchy bass":** A standard description for the audio quality.
# *   **"Seamless":** Almost universally used to describe the Bluetooth pairing process with both iOS and Android.
# *   **"Like AirPods":** Used to describe the integration features (battery pop-ups, "Find My" app support) at a lower price point.
#
# ### 3. Comparisons with Competitor Products
# *   **AirPods Pro:** Many reviewers compared the Studio Buds to AirPods, noting that while the Noise Cancellation (ANC) isn't as strong as the AirPods Pro, the sound quality is "on par" and the price is significantly lower.
# *   **Beats Fit Pro:** This was the most common internal comparison. Users noted the Fit Pro has a more secure fit for athletes due to the "wingtip," but some found the Studio Buds more comfortable for "chill around the house" use.
# *   **Samsung Galaxy Buds:** One reviewer described the Samsung buds as "ugly," looking like a "large beetle" in the ear, and preferred the Beats for their "visible brand placement" and physical buttons.
# *   **Bose QuietComfort:** While acknowledging Bose has "unmatched" noise canceling, reviewers felt the Beats were a better value for those who prioritize bass and a smaller case.
# *   **Raycon E55:** A former Raycon user switched to Beats because Raycon moved toward touch sensors, whereas they preferred the Beats' manual buttons.
#
# ### 4. Unexpected or Unique Feedback
# *   **The "Oven Survival" Story:** One user accidentally dropped an earbud into a hot oven near a gas flame. After it cooled down and "rested" for a day, it returned to perfect working order.
# *   **The "Snooping" Feature:** One reviewer pointed out that the Transparency/Awareness mode is "great if you are hard of hearing, or just enjoy **snooping on conversations** out of reach."
# *   **The Volume "Hack":** A unique technical tip was shared to fix "quiet" audio: users should map the "long press" to volume control, max it out on the bud itself, and then switch the setting back to Noise Control.
# *   **Interchangeability:** One user noted as a "perk" that they were able to swap the earbuds into the opposite ears (Left in Right, Right in Left) and still find them comfortable, which is rare for shaped earbuds.
# *   **Marital "Noise Cancellation":** A humorous note from a user mentioned they use the ANC to "barely hear your wife... err, I meant power tools."

# %% [markdown]
# #Comparative Analysis

# %%
def analyze_comparative_reviews(reviews_dict):
    # Combine all product names for the prompt
    products_list = ", ".join(reviews_dict.keys())

    prompt_message = f"""Compare customer feedback across these products: {products_list}

    For each product, analyze:
    1. Standout features and unique selling points
    2. Common complaints or limitations
    3. Price-to-value perception
    4. Target user preferences

    Then compare:
    1. Key differences in customer satisfaction
    2. Feature preferences across products
    3. Quality and reliability mentions

    Format as a structured comparison with specific examples."""

    # Combine reviews with product labels
    combined_reviews = []
    for product, reviews in reviews_dict.items():
        labeled_reviews = [f"[{product}] {review}" for review in reviews]
        combined_reviews.extend(labeled_reviews[:20])  # Take first 20 reviews per product

    return analyze_reviews(combined_reviews, api_key, prompt_message)

# %%
# Example: Compare two products
products_to_compare = ['Beats Studio Buds', 'Sennheiser CX True Wireless Earbuds']
reviews_dict = {}
for product in products_to_compare:
    reviews = df[df['short_name'] == product]['content'].tolist()[:20]
    reviews_dict[product] = reviews

comparison_insights = analyze_comparative_reviews(reviews_dict)
print(comparison_insights)
# Out:
# Based on the customer feedback provided, here is a detailed comparison between the **Beats Studio Buds** and the **Sennheiser CX True Wireless Earbuds**.
#
# ---
#
# ### **Product Analysis: Beats Studio Buds**
#
# **1. Standout Features & Unique Selling Points**
# *   **Physical "Clicky" Buttons:** This is the most praised feature. Users love the tactile feedback and the fact that it eliminates the accidental triggers common with touch-sensitive sensors.
# *   **Apple Ecosystem Integration:** They pair seamlessly with iPhones (showing the pop-up battery window) and support spatial audio/Dolby Atmos.
# *   **Bass-Heavy Sound Profile:** Reviewers noted a "punchy" and "gravitas" filled sound, specifically catered to hip-hop, metal, and EDM.
# *   **Aesthetics and Portability:** The earbuds are lightweight, "not terribly obtrusive," and come in vibrant colors like red and pink.
#
# **2. Common Complaints or Limitations**
# *   **Insecure Fit for Activity:** A frequent complaint is that they slide out during workouts or when the user sweats. One user noted they fell out just by the user turning their head or chewing.
# *   **Subpar Noise Cancellation:** Many described the ANC as "average," "noise-reducing rather than canceling," or even "a joke" compared to the AirPods Pro.
# *   **Build Quality:** Several users felt the case was "cheap plastic" with a "flimsy hinge."
# *   **Microphone Issues:** Performance on PCs and during calls was often described as "muffled" or "robotic."
#
# **3. Price-to-Value Perception**
# *   **Highly Price-Sensitive:** The consensus is that they are an **excellent value at a sale price** (around $75–$100) but are **not worth the full $150 retail price** due to the lack of wireless charging and average ANC.
#
# **4. Target User Preferences**
# *   Casual listeners and gym-goers (who don't sweat excessively) who prioritize a bass-forward sound and tactile controls over audiophile-grade neutrality.
#
# ---
#
# ### **Product Analysis: Sennheiser CX True Wireless Earbuds**
#
# **1. Standout Features & Unique Selling Points**
# *   **Superior Sound Fidelity:** Multiple users described the audio as "incredible" and "4K compared to standard definition," noting clear separation between instruments.
# *   **Exceptional Battery Life:** The earbuds boast a long runtime, with some users getting 7–9 hours on a single charge and multiple reloads from the case.
# *   **Customizable App:** The "Smart Control" app allows for EQ adjustments, which users found vital for unlocking the earbuds' full potential.
# *   **Passive Isolation:** Even without Active Noise Cancellation (ANC), the "snug fit" provides effective passive blocking of outside noise.
#
# **2. Common Complaints or Limitations**
# *   **Connectivity Frustrations:** This is the primary "deal-breaker." Users reported frequent "half-connections" (only one bud working), difficulty switching between devices, and long firmware update times (40+ minutes).
# *   **Bulky Ergonomics:** The "large and square" shape was noted to be uncomfortable for long periods, with some users reporting that the buds "dig into the ears" or fall out when the user smiles.
# *   **Poor Microphone in Noise:** While decent in quiet rooms, the mic picks up all background noise (like keyboards or road noise), making them "unusable for conversation" in public.
# *   **Complicated Setup:** Users struggled with hidden plastic films on charging contacts and a lack of clear instructions in the "Quick Guide."
#
# **3. Price-to-Value Perception**
# *   **Audiophile Bargain:** Users feel these offer the **best sound quality available under $200**. However, the "electronics/wiring issues" lead some to feel the value is diminished by poor reliability.
#
# **4. Target User Preferences**
# *   Budget-conscious audiophiles and stationary listeners who prioritize high-fidelity music and battery longevity over high-tech features or workout stability.
#
# ---
#
# ### **Head-to-Head Comparison**
#
# #### **1. Key Differences in Customer Satisfaction**
# *   **Beats** users are generally satisfied with the **user experience** (pairing, buttons, size) but dissatisfied with the **physical fit**.
# *   **Sennheiser** users are highly satisfied with the **acoustic performance** but deeply frustrated by **software and connectivity bugs**.
#
# #### **2. Feature Preferences Across Products**
# *   **Controls:** Beats users explicitly prefer the physical buttons to avoid accidental touches. Sennheiser users appreciate the app-based customization of touch controls but find the hardware itself less intuitive.
# *   **Ecosystem:** Beats is the clear winner for Apple users due to the "AirPod-like" pairing. Sennheiser is preferred by those who want to "tweak" their sound via an equalizer, which the Beats app lacks.
# *   **Active vs. Passive:** Beats offers "average" ANC; Sennheiser offers no ANC but relies on high-quality passive isolation. Users seeking total silence generally found both products slightly lacking compared to premium models (like Bose or AirPods Pro).
#
# #### **3. Quality and Reliability Mentions**
# *   **Durability:** Interestingly, Beats were noted to survive "the washer and dryer three times," while several Sennheiser users reported hardware failure (one earbud dying) after 8–11 months.
# *   **Connectivity Reliability:** Beats have a "Class 1 Bluetooth" stable connection. Sennheiser is frequently hounded by "electronics issues," with one user dropping their rating from 5 stars to 1 star after a year of connectivity headaches.
#
# ### **Summary Comparison Table**
#
# | Feature | Beats Studio Buds | Sennheiser CX True Wireless |
# | :--- | :--- | :--- |
# | **Primary Strength** | Ease of use & physical buttons | Exceptional high-fidelity sound |
# | **Primary Weakness** | Stability in ear (falls out) | Connectivity/Bluetooth bugs |
# | **Bass Performance** | Heavy, "punchy" (Fixed) | Strong but "balanced" (Adjustable) |
# | **Best For...** | Daily commutes & Apple users | Critical listening & long battery needs |
# | **Physical Design** | Small, sleek, round | Large, square, bulky |
# | **Best Value At...** | $75 - $100 (On Sale) | $100 - $130 (Standard) |

# %% [markdown]
# ##Feature-Specific Analysis

# %%
def analyze_feature(reviews, feature_name):
    prompt_message = f"""Analyze mentions of {feature_name} in these reviews:
    1. How do customers describe the {feature_name}?
    2. What specific aspects are praised or criticized?
    3. How does {feature_name} compare across products?
    4. What improvements do customers suggest?

    Include specific quotes and examples."""

    return analyze_reviews(reviews, api_key, prompt_message)

# %%
# Example: Analyze battery life mentions
battery_reviews = df[
    df['content'].str.contains('battery|charge|power', case=False, na=False)
]['content'].tolist()[:1500]

battery_insights = analyze_feature(battery_reviews, "battery life")
print(battery_insights)
# Out:
# Based on the reviews provided, here is an analysis of battery life mentions:
#
# ### 1. How customers describe the battery life
# Customer descriptions of battery life vary significantly depending on the brand and specific use case (e.g., music vs. sleep vs. ANC).
#
# *   **Positive/High Praise:** Some users describe the battery life as **"incredible,"** **"ridiculous long,"** and **"excellent."** One Anker user claimed they have **"magic pods since they live at 100%"** and can go weeks without charging the case.
# *   **Average/Serviceable:** Many customers find the battery life **"decent"** or **"good for the size."** Several reviewers mention getting **4 to 5 hours** of continuous play with Active Noise Cancellation (ANC) enabled.
# *   **Negative/Low:** Others find the battery life a **"major disappointment"** or **"low."** Specifically, for the 1More ComfoBuds Mini, several users noted they **"won't last you a full night's sleep"** if used for sleeping.
#
# ### 2. Specific aspects praised or criticized
# **Praised:**
# *   **Case Replenishment:** Multiple reviewers noted that while the earbuds might drain quickly, the **"charging case replenishes life fairly quickly."**
# *   **Standby Time:** The Anker Soundcore Life P3 was specifically praised for its standby time: **"I can keep these in my bag for a month or more... and they will still have a 100% charge."**
# *   **Fast Charging:** The Apple AirPods (2nd Gen) were praised for their quick-charge feature, where **"15 minutes of charging time is equivalent to 2 hours of talk/listening."**
#
# **Criticized:**
# *   **ANC Drain:** The most common criticism is the impact of ANC on longevity. Users noted that with ANC on, life drops to around **4 hours**, which is **"significantly less than all of the other wireless earbuds I’ve owned."**
# *   **Case Connection Issues:** Several users complained about hardware/software flaws where earbuds do not disconnect when placed in the case, causing them to **"drain the battery/not charge"** while sitting in the case.
# *   **Inconsistency:** Some users experienced one bud dying significantly faster than the other: **"my left earbud will die almost an hour before my right one does."**
#
# ### 3. Comparison across products
# The reviews suggest a clear hierarchy in battery performance:
#
# *   **The Leaders (Anker & Apple):** Anker Soundcore Life P3 is frequently cited as the longevity king: **"Battery life is excellent... last me much longer than any other earbud."** Apple AirPods are noted for their reliable total battery life (24+ hours with the case).
# *   **The Middle Ground (JBL & HTC):** JBL and HTC models are described as having **"great battery life"** that typically lasts **"all day at work"** or provides **"7 hours on a single charge."**
# *   **The Underperformers (1More & Beats):** The 1More ComfoBuds Mini are repeatedly called out for low battery life due to their small size: **"The battery life is not great (wear down in a couple hours)."** Similarly, one Beats user called their battery a **"major disappointment"** at only **3–3.5 hours**.
#
# ### 4. Improvements customers suggest
# *   **Higher Targets for Flights:** One user suggested that **"8 hours needs to be the target to get you through long haul flights,"** as many current models fall short.
# *   **Better Status Indicators:** Reviewers want more than just one LED on the case: **"It would've been nice to get maybe another 1 or 2 LED battery indicators... to let users know how much battery life is left in the case."**
# *   **Automatic Shut-off:** Customers want more reliable sensors so the buds stop draining battery the moment they are removed: **"Auto pauses when you take one out... I wish the app let you adjust the sound settings manually."**
# *   **Longer Cables:** Several reviews complained about the **"tiny"** or **"dinky"** charging cables provided, making it difficult to charge the case easily.
#
# ### Specific Quotes for Reference:
# *   **On 1More:** *"They last around 4 hours with ANC enabled, so they won't last you a full night's sleep."*
# *   **On Anker:** *"Ridiculous long battery life... mostly [charge] because I feel ashamed I haven't in so long."*
# *   **On Case Issues:** *"Putting the earbuds in the case and closing it does not seem to be an ‘off switch.’ The vast majority of the time they would reconnect while not in use and drain the battery."*
# *   **On Beats:** *"Battery life is a major disappointment... mere 3-3.5 hours of use before reaching a critical 15% charge."*
